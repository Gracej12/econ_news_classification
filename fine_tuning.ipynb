# %%
import pandas as pd

import torch
from transformers import RobertaTokenizer, RobertaForSequenceClassification
import numpy as np

# %%
# Load tokenizer
tokenizer = RobertaTokenizer.from_pretrained("roberta-base", do_lower_case=True)

# Load your fine-tuned model from the local directory
model_path = "/Users/scrubscrub/ppol6801/final_project/econ_classification_model"
my_model = RobertaForSequenceClassification.from_pretrained(model_path)

# Move model to CPU
device = torch.device("cpu")
my_model = my_model.to(device)

# Put model in evaluation mode
my_model.eval()

# Define label dictionary
label_dict = {3: "inflation", 4: "national debt", 0: "GDP", 2: "housing", 5: "stock market", 1: "employment/wages"}

max_len = 200
def predict(sentence):
    sentence = tokenizer.encode_plus(sentence, return_tensors='pt', max_length=max_len, truncation=True)
    outputs = my_model(sentence["input_ids"], attention_mask=sentence["attention_mask"])
    outputs = outputs[0].detach().numpy()
    predicted_label = np.argmax(outputs)
    label = label_dict[predicted_label]
    return predicted_label, label

predict("help i cant afford any groceries its so expensive")
# Out:
# (3, 'inflation')

# %%
econ_news = pd.read_csv('data/econ_news.csv')

#replacing null source values with the source.name value if there is one
for index, row in econ_news.iterrows():
    if pd.isna(row['source']) and not pd.isna(row['source.name']):
        econ_news.at[index, 'source'] = row['source.name']
        
#replacing null published date values with the publishedAt value if there is one
for index, row in econ_news.iterrows():
    if pd.isna(row['published date']) and not pd.isna(row['publishedAt']):
        econ_news.at[index, 'published date'] = row['publishedAt']
        
# replacing null values in extracted_content with the description
for index, row in econ_news.iterrows():
    if pd.isna(row['extracted_content']) and not pd.isna(row['description']):
        econ_news.at[index, 'extracted_content'] = row['description']
        
econ_news
# Out:
#       Unnamed: 0                                              title  \
# 0            0.0  Circular economy: definition, importance and b...
# 1            1.0  ICYMI: California Poised to Become World's 4th...
# 2            2.0  A snapshot of a new working-from-home economy ...
# 3            3.0  Recreation Economy for Rural Communities | US ...
# 4            4.0  The Political Economy of Economic Policy - IMF...
# ...          ...                                                ...
# 4119         NaN  'Bidenomics': Some House Democrats cool on Joe...
# 4120         NaN  Yale professor: Biden's economy most successfu...
# 4121         NaN  Bidenomics: White House adviser Jared Bernstei...
# 4122         NaN  The Big Squeeze: How Biden's Environmental Jus...
# 4123         NaN  WATCH: Biden touts economy and green energy in...
#
#                                             description  \
# 0     Circular economy: definition, importance and b...
# 1     ICYMI: California Poised to Become World's 4th...
# 2     A snapshot of a new working-from-home economy ...
# 3     Recreation Economy for Rural Communities | US ...
# 4     The Political Economy of Economic Policy - IMF...
# ...                                                 ...
# 4119  'Bidenomics': Some House Democrats cool on Joe...
# 4120  Yale professor: Biden's economy most successfu...
# 4121  Bidenomics: White House adviser Jared Bernstei...
# 4122  The Big Squeeze: How Biden's Environmental Jus...
# 4123  WATCH: Biden touts economy and green energy in...
#
#                      published date  \
# 0     Wed, 24 May 2023 07:00:00 GMT
# 1     Mon, 24 Oct 2022 07:00:00 GMT
# 2     Mon, 29 Jun 2020 07:00:00 GMT
# 3     Wed, 06 Dec 2023 08:00:00 GMT
# 4     Fri, 10 Jun 2022 22:51:41 GMT
# ...                             ...
# 4119  Tue, 29 Aug 2023 07:00:00 GMT
# 4120  Tue, 25 Jul 2023 07:00:00 GMT
# 4121  Wed, 28 Jun 2023 07:00:00 GMT
# 4122  Thu, 07 Sep 2023 07:00:00 GMT
# 4123  Fri, 13 Oct 2023 07:00:00 GMT
#
#                                                     url  \
# 0     https://news.google.com/rss/articles/CBMidWh0d...
# 1     https://news.google.com/rss/articles/CBMiX2h0d...
# 2     https://news.google.com/rss/articles/CBMiR2h0d...
# 3     https://news.google.com/rss/articles/CBMiRGh0d...
# 4     https://news.google.com/rss/articles/CBMiamh0d...
# ...                                                 ...
# 4119  https://news.google.com/rss/articles/CBMiemh0d...
# 4120  https://news.google.com/rss/articles/CBMiemh0d...
# 4121  https://news.google.com/rss/articles/CBMid2h0d...
# 4122  https://news.google.com/rss/articles/CBMiaWh0d...
# 4123  https://news.google.com/rss/articles/CBMiemh0d...
#
#                                source  \
# 0                 European Parliament
# 1     Office of Governor Gavin Newsom
# 2            Stanford University News
# 3                        U.S. EPA.gov
# 4         International Monetary Fund
# ...                               ...
# 4119                        USA TODAY
# 4120                            MSNBC
# 4121                              NPR
# 4122              Manhattan Institute
# 4123                     PBS NewsHour
#
#                                       extracted_content author urlToImage  \
# 0     Benefits: why do we need to switch to a circul...    NaN        NaN
# 1     ICYMI: California Poised to Become World's 4th...    NaN        NaN
# 2     The new “working-from-home economy,” which is ...    NaN        NaN
# 3     The Recreation Economy for Rural Communities p...    NaN        NaN
# 4     5 min (1403 words) Read\n\nDownload PDF\n\nWe ...    NaN        NaN
# ...                                                 ...    ...        ...
# 4119  STRATHAM, N.H. − While President Joe Biden tou...    NaN        NaN
# 4120  MSNBC's Lawrence O'Donnell is joined by Yale P...    NaN        NaN
# 4121  Remember Reaganomics? Freakonomics? Now there'...    NaN        NaN
# 4122  Executive Summary\n\nFrom its first week in of...    NaN        NaN
# 4123  PHILADELPHIA (AP) — President Joe Biden return...    NaN        NaN
#
#      publishedAt content source.id source.name
# 0            NaN     NaN       NaN         NaN
# 1            NaN     NaN       NaN         NaN
# 2            NaN     NaN       NaN         NaN
# 3            NaN     NaN       NaN         NaN
# 4            NaN     NaN       NaN         NaN
# ...          ...     ...       ...         ...
# 4119         NaN     NaN       NaN         NaN
# 4120         NaN     NaN       NaN         NaN
# 4121         NaN     NaN       NaN         NaN
# 4122         NaN     NaN       NaN         NaN
# 4123         NaN     NaN       NaN         NaN
#
# [4124 rows x 13 columns]

# %%
econ_news.dropna(subset=['extracted_content'], inplace=True)
econ_news.isna().sum()

econ_news['predicted_label'] = econ_news['extracted_content'].apply(predict)

# %%
econ_news
# Out:
#       Unnamed: 0                                              title  \
# 0            0.0  Circular economy: definition, importance and b...
# 1            1.0  ICYMI: California Poised to Become World's 4th...
# 2            2.0  A snapshot of a new working-from-home economy ...
# 3            3.0  Recreation Economy for Rural Communities | US ...
# 4            4.0  The Political Economy of Economic Policy - IMF...
# ...          ...                                                ...
# 4119         NaN  'Bidenomics': Some House Democrats cool on Joe...
# 4120         NaN  Yale professor: Biden's economy most successfu...
# 4121         NaN  Bidenomics: White House adviser Jared Bernstei...
# 4122         NaN  The Big Squeeze: How Biden's Environmental Jus...
# 4123         NaN  WATCH: Biden touts economy and green energy in...
#
#                                             description  \
# 0     Circular economy: definition, importance and b...
# 1     ICYMI: California Poised to Become World's 4th...
# 2     A snapshot of a new working-from-home economy ...
# 3     Recreation Economy for Rural Communities | US ...
# 4     The Political Economy of Economic Policy - IMF...
# ...                                                 ...
# 4119  'Bidenomics': Some House Democrats cool on Joe...
# 4120  Yale professor: Biden's economy most successfu...
# 4121  Bidenomics: White House adviser Jared Bernstei...
# 4122  The Big Squeeze: How Biden's Environmental Jus...
# 4123  WATCH: Biden touts economy and green energy in...
#
#                      published date  \
# 0     Wed, 24 May 2023 07:00:00 GMT
# 1     Mon, 24 Oct 2022 07:00:00 GMT
# 2     Mon, 29 Jun 2020 07:00:00 GMT
# 3     Wed, 06 Dec 2023 08:00:00 GMT
# 4     Fri, 10 Jun 2022 22:51:41 GMT
# ...                             ...
# 4119  Tue, 29 Aug 2023 07:00:00 GMT
# 4120  Tue, 25 Jul 2023 07:00:00 GMT
# 4121  Wed, 28 Jun 2023 07:00:00 GMT
# 4122  Thu, 07 Sep 2023 07:00:00 GMT
# 4123  Fri, 13 Oct 2023 07:00:00 GMT
#
#                                                     url  \
# 0     https://news.google.com/rss/articles/CBMidWh0d...
# 1     https://news.google.com/rss/articles/CBMiX2h0d...
# 2     https://news.google.com/rss/articles/CBMiR2h0d...
# 3     https://news.google.com/rss/articles/CBMiRGh0d...
# 4     https://news.google.com/rss/articles/CBMiamh0d...
# ...                                                 ...
# 4119  https://news.google.com/rss/articles/CBMiemh0d...
# 4120  https://news.google.com/rss/articles/CBMiemh0d...
# 4121  https://news.google.com/rss/articles/CBMid2h0d...
# 4122  https://news.google.com/rss/articles/CBMiaWh0d...
# 4123  https://news.google.com/rss/articles/CBMiemh0d...
#
#                                source  \
# 0                 European Parliament
# 1     Office of Governor Gavin Newsom
# 2            Stanford University News
# 3                        U.S. EPA.gov
# 4         International Monetary Fund
# ...                               ...
# 4119                        USA TODAY
# 4120                            MSNBC
# 4121                              NPR
# 4122              Manhattan Institute
# 4123                     PBS NewsHour
#
#                                       extracted_content author urlToImage  \
# 0     Benefits: why do we need to switch to a circul...    NaN        NaN
# 1     ICYMI: California Poised to Become World's 4th...    NaN        NaN
# 2     The new “working-from-home economy,” which is ...    NaN        NaN
# 3     The Recreation Economy for Rural Communities p...    NaN        NaN
# 4     5 min (1403 words) Read\n\nDownload PDF\n\nWe ...    NaN        NaN
# ...                                                 ...    ...        ...
# 4119  STRATHAM, N.H. − While President Joe Biden tou...    NaN        NaN
# 4120  MSNBC's Lawrence O'Donnell is joined by Yale P...    NaN        NaN
# 4121  Remember Reaganomics? Freakonomics? Now there'...    NaN        NaN
# 4122  Executive Summary\n\nFrom its first week in of...    NaN        NaN
# 4123  PHILADELPHIA (AP) — President Joe Biden return...    NaN        NaN
#
#      publishedAt content source.id source.name     predicted_label
# 0            NaN     NaN       NaN         NaN            (0, GDP)
# 1            NaN     NaN       NaN         NaN            (0, GDP)
# 2            NaN     NaN       NaN         NaN            (0, GDP)
# 3            NaN     NaN       NaN         NaN        (2, housing)
# 4            NaN     NaN       NaN         NaN      (3, inflation)
# ...          ...     ...       ...         ...                 ...
# 4119         NaN     NaN       NaN         NaN            (0, GDP)
# 4120         NaN     NaN       NaN         NaN            (0, GDP)
# 4121         NaN     NaN       NaN         NaN            (0, GDP)
# 4122         NaN     NaN       NaN         NaN      (3, inflation)
# 4123         NaN     NaN       NaN         NaN  (4, national debt)
#
# [4124 rows x 14 columns]

# %%
econ_news.to_csv('data/classified_econ_news.csv')
